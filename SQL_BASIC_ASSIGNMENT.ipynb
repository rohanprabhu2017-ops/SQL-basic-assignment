# %%
from typing import ValuesView
from IPython.core.history import datetime
#QUESTION1 ANSWER
CREATE DATABASE comapny_db;
use company_db;
create table emplyoees(
    employee_id int primary key,
    first_name varchar(50),
    last_name varchar(50),
    department varchar(50),
    salary int,
    hire_date DATE
);

#QUESTION 2 ANSWER
INSERT INTO employees (employee_id, first_name, last_name, department, salary, hire_date)
VALUES
(101, 'Amit', 'Sharma', 'HR', 50000, '2020-01-15'),
(102, 'Riya', 'Kapoor', 'Sales', 75000, '2019-03-22'),
(103, 'Raj', 'Mehta', 'IT', 90000, '2018-07-11'),
(104, 'Neha', 'Verma', 'IT', 85000, '2021-09-01'),
(105, 'Arjun', 'Singh', 'Finance', 60000, '2022-02-10');

#QUESTION 3 ANSWER
SELECT * FROM employees
ORDER BY salary ASC;

#QUESTION 4 ANSWER
SELECT * FROM employees
ORDER BY department ASC, salary DESC;

#QUESTION 5 ANSWER
SELECT * FROM employees
WHERE department ='IT'
ORDER BY hire_date DESC;

#QUESTION 6 ANSWER
CREATE TABLE sales (
    sale_id INT PRIMARY KEY,
    customer_name VARCHAR(50),
    amount INT,
    sale_date DATE
);
INSERT INTO sales (sale_id, customer_name, amount, sale_date) VALUES
(1, 'Aditi', 1500, '2024-08-01'),
(2, 'Rohan', 2200, '2024-08-03'),
(3, 'Aditi', 3500, '2024-09-05'),
(4, 'Meena', 2700, '2024-09-15'),
(5, 'Rohan', 4500, '2024-09-25');

#QUESTION 7 ANSWER
SELECT * FROM sales
ORDER BY amount DESC;

#QUESTION 8 ANSWER
SELECT * FROM sales
WHERE customer_name = 'Aditi';

#QUESTION 9 ANSWER
"""
Primary Key: A unique identifier for every record in a table. It cannot contain
NULL values and ensures that each row is distinct.
Foreign Key: A column (or group of columns) that provides a link between
 in two tables. It refers to the Primary Key of another table to maintain
referential integrity.
"""
"""
#QUESTION 10 ANSWER
Constraints are rules applied to table columns to limit the type of data that
 can go into a table.
 Why they are used:
 To ensure the accuracy and reliability of the data.
 To maintain data integrity.
 Examples include NOT NULL, UNIQUE, PRIMARY KEY, FOREIGN KEY, and CHECK.
 """
# Out:
#   File "/tmp/ipykernel_567/4221352858.py", line 2
#     CREATE DATABASE comapny_db;
#            ^
# SyntaxError: invalid syntax
